# %% [markdown]
# <a href="https://colab.research.google.com/github/therealcaesar-si/EMSC2010-W2-P2-u7567593/blob/main/EMSC2010_W2_P2_NB2_Seth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010_W2_P2_NB2
# ---
#
# *   Class: EMSC2010
# *   Week: 2
# *   Session: Practical 2
#
# ---
#
# From GitHub, you can open this notebook in Google Colab using the 'Open in Colab' button. Then:
#
# 1. Change the notebook name to include your U-number (e.g EMSC2010_W2_P2_NB2_uXXXXXXX.ipynb)
# 2. Save to Google Drive (*File* >>> *Save a copy in Drive*)
# 3. Click *Share* (top right of window)
# 4. Add the **Gmail** addresses of your group and send them a notification
#
# Your group should then open the notebook and:
#
# 5. Write the code for the Fermi estimation problem
#
# The group's edits will still be saved in your Google Drive. Once you can see the edits:
#
# 6. Commit to GitHub (*File* >>> *Save a copy in GitHub*)
# 7. Select the repository for your commit (same as your original repository)
# 8. Give a brief commit message (e.g. 'Commit including Bob's updates')
# 9. Check your GitHub repository, a copy of your notebook should be there.
#
# ---
#
# Because Google Drive is saving your work and the work of your collaborators automatically, you don't need to commit all minor edits to GitHub. Rather commit when you want to archive a version of your notebook because you have completed a substantial task.

# %% [markdown]
# # Group name: Bob's group
# # Fermi estimation problem: The mass of the oceans
#
# ### This code was written by Bob based on ideas discussed with Alice

# %%
X = 1 + 1 #set X to 1+1 (Bob)

# %% [markdown]
# # Fermi estimation: How many cars are registered in Canberra?

# %%
opulation = 500000 # population of Canberra is approximately 500000
people = 3 # approximately 3 people per household

household = population / people #number of households

print (household)
# Out:
# 166666.66666666666

# %%
cars = 2.5 #approx number of cars per household

registrations = household * cars #estimate for number of cars registered in Canberra

print (registrations)
# Out:
# 416666.6666666666

# %% [markdown]
# # How many of the cars registered in Canberra are EVs?

# %%
(7/100) * registrations #12% of all new cars in Aus are electric, Canberra has one of the highest uptakes of EVs -> 7%?
# Out:
# 29166.666666666668
